# %% [markdown]
# ## New York Yankees: A Sentiment Analysis of MLB Performance

# %%
#Install reqired libraries
# !pip install beautifulsoup4 requests
# !pip install tqdm
# !pip install pandas
# !pip install matplotlib
# !pip install lxml
# !pip install nltk
# !pip install wordcloud
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (4.12.2)
# Requirement already satisfied: requests in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (2.27.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from beautifulsoup4) (2.4.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from requests) (1.26.8)
# Requirement already satisfied: tqdm in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (4.65.0)
# Requirement already satisfied: colorama in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from tqdm) (0.4.4)
# Requirement already satisfied: pandas in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (2.0.2)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (3.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.7.0)
# Requirement already satisfied: six>=1.5 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: lxml in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (4.9.2)
# Requirement already satisfied: nltk in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (3.8.1)
# Requirement already satisfied: tqdm in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from nltk) (2023.6.3)
# Requirement already satisfied: click in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: colorama in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from click->nltk) (0.4.4)
# Requirement already satisfied: wordcloud in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (1.9.2)
# Requirement already satisfied: pillow in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib->wordcloud) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib->wordcloud) (4.40.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.7.0)
# Requirement already satisfied: six>=1.5 in c:\users\andre\downloads\new folder\envs\r\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
#Import required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import lxml

import os
import re
import numpy as np
import string
import glob
import nltk
from wordcloud import WordCloud
from collections import Counter, defaultdict
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from string import punctuation
from tqdm import tqdm

sw = stopwords.words("english")

# %% [markdown]
# The first step is to scrape the text from the blog posts from the mlbtraderumors.com website. The posts include text, dates posted, and the authors name, all of which will be scraped before storing into a dataframe to use and start the text analysis.

# %%
def scrape_website(url, file_path):
    # Send a GET request to the website
    response = requests.get(url)

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, "html.parser")

    # Find all the news article elements
    articles = soup.find_all("article")

    # Create lists to store the extracted values
    titles = []
    authors = []
    dates = []
    contents = []

    # Iterate over the articles and extract the text
    with open(file_path, "w", encoding="utf-8") as file:
        for article in articles:
            # Extract the article title
            title_element = article.find("h2")
            title = title_element.text.strip() if title_element else ""
            titles.append(title)

            # Extract the article author
            author_element = article.find("span", class_="entry-author")
            author = author_element.text.strip() if author_element else ""
            authors.append(author)

            # Extract the article date
            date_element = article.find("time", class_="entry-time")
            date = date_element.text.strip() if date_element else ""
            dates.append(date)

            # Extract the article content
            content_element = article.find("div", class_="entry-content")
            content = content_element.text.strip() if content_element else ""
            contents.append(content)

            # Write the title and content to the file
            file.write("Title: " + title + "\n")
            file.write("Author: " + author + "\n")
            file.write("Date: " + date + "\n")
            file.write("Content: " + content + "\n")
            file.write("---\n")

    # Create a DataFrame from the extracted values
    data = {
        "Title": titles,
        "Author": authors,
        "Date": dates,
        "Content": contents
    }

    df = pd.DataFrame(data)

    # Drop rows without content
    df.dropna()

    return df

# %%
# URL of the website to scrape
url = "https://www.mlbtraderumors.com/new-york-yankees?show=all"
file_path = "C:/Users/andre/OneDrive/Project/mlbtraderumors_new_york_yankees_articles1.txt"

# Scrape the website, write the scraped text to a file, and get the head of the DataFrame
df = scrape_website(url, file_path)
df.head()
# Out:
#                                                Title            Author  \
# 0  Josh Donaldson Undecided About Playing Beyond ...  Darragh McDonald
# 1  Harrison Bader Expected To Be Activated On Jun...     Mark Polishuk
# 2                              Latest On Aaron Judge     Mark Polishuk
# 3  The Yankees Are Showing The Importance Of Mino...  Darragh McDonald
# 4               Yankees Notes: Payroll, Volpe, Bader    Anthony Franco
#
#             Date                                            Content
# 0  June 19, 2023  Yankees third baseman Josh Donaldson hasn’t ye...
# 1  June 18, 2023  Harrison Bader is slated to be activated from ...
# 2  June 17, 2023  Aaron Judge hasn’t played since June 3, when t...
# 3  June 15, 2023  Every offseason, there are huge moves that gra...
# 4  June 14, 2023  The Yankees sit in third place in the loaded A...

# %%
# Change the Data column to a datetime object:
df['Date'] = pd.to_datetime(df['Date'], format="%B %d, %Y", errors= 'coerce')

# %%
df.dtypes
# Out:
# Title              object
# Author             object
# Date       datetime64[ns]
# Content            object
# dtype: object

# %%
# Check for missing values
df.isna().sum()
# Out:
# Title       0
# Author      0
# Date       30
# Content     0
# dtype: int64

# %%
len(df)
# Out:
# 1030

# %%
df = df.dropna()
df
# Out:
#                                                  Title            Author  \
# 0    Josh Donaldson Undecided About Playing Beyond ...  Darragh McDonald
# 1    Harrison Bader Expected To Be Activated On Jun...     Mark Polishuk
# 2                                Latest On Aaron Judge     Mark Polishuk
# 3    The Yankees Are Showing The Importance Of Mino...  Darragh McDonald
# 4                 Yankees Notes: Payroll, Volpe, Bader    Anthony Franco
# ..                                                 ...               ...
# 995         A Mariners-Yankees Blockbuster That Busted      Connor Byrne
# 996                  Adam Warren Discusses Free Agency     Mark Polishuk
# 997     Yankees Co-Owner Hank Steinbrenner Passes Away         Jeff Todd
# 998           A Potential Breakout Slugger For Yankees      Connor Byrne
# 999                 Mark Reynolds Announces Retirement       Steve Adams
#
#           Date                                            Content
# 0   2023-06-19  Yankees third baseman Josh Donaldson hasn’t ye...
# 1   2023-06-18  Harrison Bader is slated to be activated from ...
# 2   2023-06-17  Aaron Judge hasn’t played since June 3, when t...
# 3   2023-06-15  Every offseason, there are huge moves that gra...
# 4   2023-06-14  The Yankees sit in third place in the loaded A...
# ..         ...                                                ...
# 995 2020-04-22  If we go back eight years to January 2012, we’...
# 996 2020-04-19  Adam Warren headed into the free agent market ...
# 997 2020-04-14  Yankees co-owner Hank Steinbrenner has passed ...
# 998 2020-04-13  Despite the myriad injuries they faced a year ...
# 999 2020-04-09  Veteran slugger Mark Reynolds, who enjoyed a 1...
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## Cleaning the Data

# %%
#Identify any noise in the data
RE_SUSPICIOUS = re.compile(r'[&#<>{}\[\]\\]')

def impurity(text, min_len=10):
    """returns the share of suspicious characters in a text"""
    if text == None or len(text) < min_len:
        return 0
    else:
        return len(RE_SUSPICIOUS.findall(text))/len(text)

# %%
df['Content'].apply
# Out:
# <bound method Series.apply of 0      Yankees third baseman Josh Donaldson hasn’t ye...
# 1      Harrison Bader is slated to be activated from ...
# 2      Aaron Judge hasn’t played since June 3, when t...
# 3      Every offseason, there are huge moves that gra...
# 4      The Yankees sit in third place in the loaded A...
#                              ...
# 995    If we go back eight years to January 2012, we’...
# 996    Adam Warren headed into the free agent market ...
# 997    Yankees co-owner Hank Steinbrenner has passed ...
# 998    Despite the myriad injuries they faced a year ...
# 999    Veteran slugger Mark Reynolds, who enjoyed a 1...
# Name: Content, Length: 1000, dtype: object>

# %%
pd.options.display.max_colwidth = 100 ###
# add new column to data frame
df['impurity'] = df['Content'].apply(impurity, min_len=10)

# get the top 3 records
df[['Content', 'impurity']].sort_values(by='impurity', ascending=False).head(3)
# Out:
#                                                                                                  Content  \
# 76   Could the Marlins match up with the Yankees on a trade involving Oswald Peraza? And which of Mia...
# 146  Major League Baseball’s international signing period for 2023 has officially opened up today, wi...
# 333  We’ll use this post to round up some of the more notable recent draft signings:\n\nThe Phillies ...
#
#      impurity
# 76   0.012195
# 146  0.005563
# 333  0.002883

# %% [markdown]
# The steps above displays the highest impurity levels for the Athletics' data set. The impurity levels above are extremely low, being below 1% of all characters in each blog post appear suspicious.

# %% [markdown]
# ## Character Normalization & Tokenization

# %%
# Example function to normalize the text in the "Contents" column
def normalize_text(text):
    # Lowercase the text
    text = text.lower()

    # Remove punctuation
    text = text.translate(str.maketrans("", "", string.punctuation))

    # Remove special characters and digits
    text = re.sub(r"[^a-zA-Z]", " ", text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words("english"))
    tokens = [token for token in tokens if token not in stop_words]

    # Perform stemming
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]

    return tokens

# Apply normalization to the "Contents" column
df["Contents_Normalized"] = df["Content"].apply(normalize_text)

# Print the head of the DataFrame with the normalized contents
df[["Content", "Contents_Normalized"]].head()
# Out:
#                                                                                                Content  \
# 0  Yankees third baseman Josh Donaldson hasn’t yet decided if he’ll continue his playing career bey...
# 1  Harrison Bader is slated to be activated from the 10-day injured list on Tuesday, Yankees manage...
# 2  Aaron Judge hasn’t played since June 3, when the Yankees superstar made a highlight-reel catch t...
# 3  Every offseason, there are huge moves that grab headlines and have the ability to transform fran...
# 4  The Yankees sit in third place in the loaded AL East despite a 39-30 record. They’re unquestiona...
#
#                                                                                    Contents_Normalized
# 0  [yanke, third, baseman, josh, donaldson, yet, decid, continu, play, career, beyond, current, cam...
# 1  [harrison, bader, slate, activ, day, injur, list, tuesday, yanke, manag, aaron, boon, told, athl...
# 2  [aaron, judg, play, sinc, june, yanke, superstar, made, highlightreel, catch, sent, crash, dodge...
# 3  [everi, offseason, huge, move, grab, headlin, abil, transform, franchis, top, free, agent, get, ...
# 4  [yanke, sit, third, place, load, al, east, despit, record, unquestion, approach, deadlin, season...

# %%
df['length'] = df['Contents_Normalized'].str.len()
df.head()
# Out:
#                                                           Title  \
# 0            Josh Donaldson Undecided About Playing Beyond 2023
# 1            Harrison Bader Expected To Be Activated On June 20
# 2                                         Latest On Aaron Judge
# 3  The Yankees Are Showing The Importance Of Minor League Deals
# 4                          Yankees Notes: Payroll, Volpe, Bader
#
#              Author       Date  \
# 0  Darragh McDonald 2023-06-19
# 1     Mark Polishuk 2023-06-18
# 2     Mark Polishuk 2023-06-17
# 3  Darragh McDonald 2023-06-15
# 4    Anthony Franco 2023-06-14
#
#                                                                                                Content  \
# 0  Yankees third baseman Josh Donaldson hasn’t yet decided if he’ll continue his playing career bey...
# 1  Harrison Bader is slated to be activated from the 10-day injured list on Tuesday, Yankees manage...
# 2  Aaron Judge hasn’t played since June 3, when the Yankees superstar made a highlight-reel catch t...
# 3  Every offseason, there are huge moves that grab headlines and have the ability to transform fran...
# 4  The Yankees sit in third place in the loaded AL East despite a 39-30 record. They’re unquestiona...
#
#    impurity  \
# 0  0.000000
# 1  0.000000
# 2  0.000602
# 3  0.000000
# 4  0.000000
#
#                                                                                    Contents_Normalized  \
# 0  [yanke, third, baseman, josh, donaldson, yet, decid, continu, play, career, beyond, current, cam...
# 1  [harrison, bader, slate, activ, day, injur, list, tuesday, yanke, manag, aaron, boon, told, athl...
# 2  [aaron, judg, play, sinc, june, yanke, superstar, made, highlightreel, catch, sent, crash, dodge...
# 3  [everi, offseason, huge, move, grab, headlin, abil, transform, franchis, top, free, agent, get, ...
# 4  [yanke, sit, third, place, load, al, east, despit, record, unquestion, approach, deadlin, season...
#
#    length
# 0     364
# 1      70
# 2     328
# 3     499
# 4     395

# %%
df['length'].plot(kind='box', vert=False, figsize=(8, 1))
# Out:
# <Axes: >

# %%
df['Title_length'] = df['Title'].str.len()
df['Title_length'].plot(kind='box', vert=False, figsize=(8, 1))
# Out:
# <Axes: >

# %%
df['length'].plot(kind='hist', bins=30, figsize=(8,2))
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Extract the month from the date and create a new column
df['Month'] = df['Date'].dt.month

# Plot the average post length
df.groupby('Month').agg({'length': 'mean'}) \
  .plot(title="Avg. Post Length", ylim=(0,500), figsize=(6,2))
# Out:
# <Axes: title={'center': 'Avg. Post Length'}, xlabel='Month'>

# %%
def count_words(df, column='Contents_Normalized', preprocess=None, min_freq=2):

    # process tokens and update counter
    def update(doc):
        tokens = doc if preprocess is None else preprocess(doc)
        counter.update(tokens)

    # create counter and run through all data
    counter = Counter()
    tqdm.pandas() #initialize tqdm for progress bar
    df[column].apply(update)

    # transform counter into data frame
    freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
    freq_df = freq_df.query('freq >= @min_freq')
    freq_df.index.name = 'token'
    
    return freq_df.sort_values('freq', ascending=False)

# %%
freq_df = count_words(df)
freq_df.head(5)
# Out:
#         freq
# token
# yanke   4277
# season  3366
# year    2493
# mm      2089
# leagu   1782

# %%
#How many tokens are in the df?
len(freq_df)
# Out:
# 6233

# %%
# top words with 10+ characters
count_words(df, column='Content', 
            preprocess=lambda Content: re.findall(r"\w{10,}", Content)).head(5)
# Out:
#              freq
# token
# appearances   784
# outfielder    324
# assignment    320
# arbitration   239
# designated    237

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(8,3))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# Import data on the New York Yankees from baseball-reference.com.
#
# https://www.baseball-reference.com/teams/NYY/attend.shtml

# %%
# URL of the webpage to scrape
url = "https://www.baseball-reference.com/teams/NYY/attend.shtml"

# Read the HTML table into a list of DataFrames
tables = pd.read_html(url)

# Select the table of interest (index 0 in this case)
table = tables[0]

# Save the DataFrame as a CSV file
file_path = "C:/Users/andre/OneDrive/Project/MLB_data/yankees_statistics.csv"
table.to_csv(file_path, index=False, header=True)

print("Data saved to", file_path)
# Out:
# Data saved to C:/Users/andre/OneDrive/Project/MLB_data/yankees_statistics.csv

# %%
path = "C:/Users/andre/OneDrive/Project/MLB_data/"

yankees_df = pd.DataFrame(pd.read_csv(path + 'yankees_statistics.csv'))
yankees_df.head()
# Out:
#    Year                Tm       Lg    W   L  Finish         Playoffs  \
# 0  2023  New York Yankees  AL East   39  33       3              NaN
# 1  2022  New York Yankees  AL East   99  63       1  Lost ALCS (4-0)
# 2  2021  New York Yankees  AL East   92  70       2  Lost ALWC (1-0)
# 3  2020  New York Yankees  AL East   33  27       2  Lost ALDS (3-2)
# 4  2019  New York Yankees  AL East  103  59       1  Lost ALCS (4-2)
#
#    Attendance  Attend/G        Rank  Est. Payroll  PPF  BPF  \
# 0   1492377.0   39273.0   1st of 15  $270,202,722   99  100
# 1   3136207.0   38719.0   1st of 15  $238,950,714   99  100
# 2   1959854.0   24196.0   3rd of 15  $209,799,047   99  100
# 3         NaN       NaN  10th of 15  $218,635,714   96   97
# 4   3304404.0   40795.0   1st of 15  $228,442,421   96   98
#
#               Stadium
# 0  Yankee Stadium III
# 1  Yankee Stadium III
# 2  Yankee Stadium III
# 3  Yankee Stadium III
# 4  Yankee Stadium III

# %%
yankees_df= yankees_df[yankees_df['Year'] > 2004]
yankees_df
# Out:
#     Year                Tm       Lg    W   L  Finish         Playoffs  \
# 0   2023  New York Yankees  AL East   39  33       3              NaN
# 1   2022  New York Yankees  AL East   99  63       1  Lost ALCS (4-0)
# 2   2021  New York Yankees  AL East   92  70       2  Lost ALWC (1-0)
# 3   2020  New York Yankees  AL East   33  27       2  Lost ALDS (3-2)
# 4   2019  New York Yankees  AL East  103  59       1  Lost ALCS (4-2)
# 5   2018  New York Yankees  AL East  100  62       2  Lost ALDS (3-1)
# 6   2017  New York Yankees  AL East   91  71       2  Lost ALCS (4-3)
# 7   2016  New York Yankees  AL East   84  78       4              NaN
# 8   2015  New York Yankees  AL East   87  75       2  Lost ALWC (1-0)
# 9   2014  New York Yankees  AL East   84  78       2              NaN
# 10  2013  New York Yankees  AL East   85  77       3              NaN
# 11  2012  New York Yankees  AL East   95  67       1  Lost ALCS (4-0)
# 12  2011  New York Yankees  AL East   97  65       1  Lost ALDS (3-2)
# 13  2010  New York Yankees  AL East   95  67       2  Lost ALCS (4-2)
# 14  2009  New York Yankees  AL East  103  59       1     Won WS (4-2)
# 15  2008  New York Yankees  AL East   89  73       3              NaN
# 16  2007  New York Yankees  AL East   94  68       2  Lost ALDS (3-1)
# 17  2006  New York Yankees  AL East   97  65       1  Lost ALDS (3-1)
# 18  2005  New York Yankees  AL East   95  67       1  Lost ALDS (3-2)
#
#     Attendance  Attend/G        Rank  Est. Payroll  PPF  BPF  \
# 0    1492377.0   39273.0   1st of 15  $270,202,722   99  100
# 1    3136207.0   38719.0   1st of 15  $238,950,714   99  100
# 2    1959854.0   24196.0   3rd of 15  $209,799,047   99  100
# 3          NaN       NaN  10th of 15  $218,635,714   96   97
# 4    3304404.0   40795.0   1st of 15  $228,442,421   96   98
# 5    3482855.0   42998.0   1st of 15  $160,643,032   98  100
# 6    3154938.0   38950.0   2nd of 15  $182,424,700  103  104
# 7    3063405.0   37820.0   2nd of 15  $193,229,350  102  103
# 8    3193795.0   39430.0   1st of 15  $214,051,957  101  101
# 9    3401624.0   41995.0   1st of 15  $258,118,959  100  100
# 10   3279589.0   40489.0   1st of 15  $246,534,750  100  100
# 11   3542406.0   43733.0   1st of 14  $197,977,900  103  104
# 12   3653680.0   45107.0   1st of 14  $206,275,028  105  106
# 13   3765807.0   46491.0   1st of 14  $210,733,389  104  106
# 14   3719358.0   45918.0   1st of 14  $210,330,039  103  105
# 15   4298655.0   53070.0   1st of 14  $212,286,789  101  103
# 16   4271083.0   52729.0   1st of 14  $207,039,045  100  101
# 17   4248067.0   52445.0   1st of 14  $194,663,079   99  101
# 18   4090696.0   50502.0   1st of 14  $208,306,817   97   98
#
#                Stadium
# 0   Yankee Stadium III
# 1   Yankee Stadium III
# 2   Yankee Stadium III
# 3   Yankee Stadium III
# 4   Yankee Stadium III
# 5   Yankee Stadium III
# 6   Yankee Stadium III
# 7   Yankee Stadium III
# 8   Yankee Stadium III
# 9   Yankee Stadium III
# 10  Yankee Stadium III
# 11  Yankee Stadium III
# 12  Yankee Stadium III
# 13  Yankee Stadium III
# 14  Yankee Stadium III
# 15   Yankee Stadium II
# 16   Yankee Stadium II
# 17   Yankee Stadium II
# 18   Yankee Stadium II

# %%
# Remove dollar, comma signs from the following columns:
yankees_df['Est. Payroll'] = yankees_df['Est. Payroll'].replace({'\$':''}, regex = True)
yankees_df['Est. Payroll'] = yankees_df['Est. Payroll'].replace({'\,':''}, regex = True)
yankees_df['Attendance'] = yankees_df['Attendance'].replace({'\,':''}, regex = True)
yankees_df['Attend/G'] = yankees_df['Attend/G'].replace({'\,':''}, regex = True)
yankees_df['Stadium'] = yankees_df['Stadium'].replace({'\,':''}, regex = True)
yankees_df.head()
# Out:
#    Year                Tm       Lg    W   L  Finish         Playoffs  \
# 0  2023  New York Yankees  AL East   39  33       3              NaN
# 1  2022  New York Yankees  AL East   99  63       1  Lost ALCS (4-0)
# 2  2021  New York Yankees  AL East   92  70       2  Lost ALWC (1-0)
# 3  2020  New York Yankees  AL East   33  27       2  Lost ALDS (3-2)
# 4  2019  New York Yankees  AL East  103  59       1  Lost ALCS (4-2)
#
#    Attendance  Attend/G        Rank Est. Payroll  PPF  BPF             Stadium
# 0   1492377.0   39273.0   1st of 15    270202722   99  100  Yankee Stadium III
# 1   3136207.0   38719.0   1st of 15    238950714   99  100  Yankee Stadium III
# 2   1959854.0   24196.0   3rd of 15    209799047   99  100  Yankee Stadium III
# 3         NaN       NaN  10th of 15    218635714   96   97  Yankee Stadium III
# 4   3304404.0   40795.0   1st of 15    228442421   96   98  Yankee Stadium III

# %%
yankees_df['Est. Payroll'] = yankees_df['Est. Payroll'].astype(float)
yankees_df.dtypes
# Out:
# Year              int64
# Tm               object
# Lg               object
# W                 int64
# L                 int64
# Finish            int64
# Playoffs         object
# Attendance      float64
# Attend/G        float64
# Rank             object
# Est. Payroll    float64
# PPF               int64
# BPF               int64
# Stadium          object
# dtype: object

# %%
yankees_df.describe()
# Out:
#               Year           W          L     Finish    Attendance  \
# count    19.000000   19.000000  19.000000  19.000000  1.800000e+01
# mean   2014.000000   87.473684  64.421053   1.894737  3.392156e+06
# std       5.627314   19.074032  13.487920   0.875261  7.320794e+05
# min    2005.000000   33.000000  27.000000   1.000000  1.492377e+06
# 25%    2009.500000   86.000000  62.500000   1.000000  3.164652e+06
# 50%    2014.000000   94.000000  67.000000   2.000000  3.442240e+06
# 75%    2018.500000   97.000000  72.000000   2.000000  3.754195e+06
# max    2023.000000  103.000000  78.000000   4.000000  4.298655e+06
#
#            Attend/G  Est. Payroll         PPF         BPF
# count     18.000000  1.900000e+01   19.000000   19.000000
# mean   43036.666667  2.141392e+08  100.263158  101.421053
# std     6950.097731  2.593502e+07    2.600045    2.673238
# min    24196.000000  1.606430e+08   96.000000   97.000000
# 25%    39312.250000  2.021265e+08   99.000000  100.000000
# 50%    42496.500000  2.103300e+08  100.000000  101.000000
# 75%    46347.750000  2.235391e+08  102.500000  103.500000
# max    53070.000000  2.702027e+08  105.000000  106.000000

# %%
# Plotting the Data
plt.figure(figsize=(10, 6))

# Plotting Attendance over the years
plt.plot(yankees_df['Year'], yankees_df['Attendance'], marker='o')
plt.xlabel('Year')
plt.ylabel('Attendance')
plt.title('Attendance of New York Yankees over the Years')
# Out:
# Text(0.5, 1.0, 'Attendance of New York Yankees over the Years')

# %%
# Plotting Wins over the years
plt.figure(figsize=(10, 6))
plt.plot(yankees_df['Year'], yankees_df['W'], marker='o')
plt.xlabel('Year')
plt.ylabel('Wins')
plt.title('Wins of New York Yankees over the Years')
# Out:
# Text(0.5, 1.0, 'Wins of New York Yankees over the Years')

# %%
# Plotting Payroll over the years
plt.figure(figsize=(10, 6))
plt.plot(yankees_df['Year'], yankees_df['Est. Payroll'], marker='o')
plt.xlabel('Year')
plt.ylabel('Payroll')
plt.title('Payroll of New York Yankees over the Years')
# Out:
# Text(0.5, 1.0, 'Payroll of New York Yankees over the Years')

# %%
# Correlation matrix
correlation = yankees_df.corr()
print(correlation)

# Heatmap of correlation matrix
plt.figure(figsize=(10, 8))
plt.imshow(correlation, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(correlation)), correlation.columns, rotation=90)
plt.yticks(range(len(correlation)), correlation.columns)
plt.title('Correlation Matrix')
# Out:
#                   Year         W         L    Finish  Attendance  Attend/G  \
# Year          1.000000 -0.445695 -0.425793  0.225589   -0.852456 -0.823493
# W            -0.445695  1.000000  0.746419 -0.443475    0.668311  0.217084
# L            -0.425793  0.746419  1.000000  0.077582    0.482187  0.018391
# Finish        0.225589 -0.443475  0.077582  1.000000   -0.334045 -0.216730
# Attendance   -0.852456  0.668311  0.482187 -0.334045    1.000000  0.837342
# Attend/G     -0.823493  0.217084  0.018391 -0.216730    0.837342  1.000000
# Est. Payroll  0.283764 -0.452365 -0.273449  0.143944   -0.421004 -0.171575
# PPF          -0.261732  0.275694  0.359131  0.067727    0.074749  0.052521
# BPF          -0.307524  0.343725  0.294097  0.001269    0.162041  0.156780
#
#               Est. Payroll       PPF       BPF
# Year              0.283764 -0.261732 -0.307524
# W                -0.452365  0.275694  0.343725
# L                -0.273449  0.359131  0.294097
# Finish            0.143944  0.067727  0.001269
# Attendance       -0.421004  0.074749  0.162041
# Attend/G         -0.171575  0.052521  0.156780
# Est. Payroll      1.000000 -0.149200 -0.262571
# PPF              -0.149200  1.000000  0.965261
# BPF              -0.262571  0.965261  1.000000
# Text(0.5, 1.0, 'Correlation Matrix')
